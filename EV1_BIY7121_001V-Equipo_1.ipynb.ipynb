# %% [markdown]
# #DUOC UC
# #Minería de datos
# ##Sección: MINERIA DE DATOS_001V
# ##Docente: Gabriel Leonardo Estivales Silva
# ##Integrantes: Pamela Rosa Aldana Rojas 15405353-0

# %% [markdown]
# # Contexto del caso semestral

# %% [markdown]
# StarCraft II es un juego de estrategia en tiempo real (RTS) desarrollado por Blizzard Entertainment. Lanzado en 2010, es la secuela
# del icónico StarCraft original. El juego se ambienta en un futuro distante, donde tres facciones, los humanos terran, los enjambres
# zerg y los misteriosos protoss, luchan por el control del sector Koprulu.<br>
# Los jugadores pueden elegir una de las tres razas, cada una con habilidades únicas y estrategias distintas. StarCraft II presenta una
# campaña envolvente con una narrativa rica y desafiantes misiones para cada raza. Además, destaca en el ámbito multijugador,
# donde jugadores de todo el mundo compiten en emocionantes batallas.<br>
# El juego ha alcanzado un estatus destacado en los deportes electrónicos (eSports), con una comunidad activa y competiciones de
# alto nivel. La gestión de recursos, la toma de decisiones estratégicas y la velocidad de ejecución son fundamentales en StarCraft II,
# lo que lo convierte en un desafío constante. Con gráficos impresionantes, una jugabilidad sólida y una escena competitiva vibrante,
# StarCraft II sigue siendo una referencia en el mundo de los juegos de estrategia en tiempo real.<br>
# En este contexto, se presentan los siguientes datos:<br><br>
#
# * GameID: Identificador único para cada partida.<br>
# * LeagueIndex: Índice de liga, que varía de 1 a 8 y representa diferentes niveles de habilidad de los jugadores.<br>
# * Age: Edad de cada jugador.<br>
# * HoursPerWeek: Horas dedicadas al juego por semana.<br>
# * TotalHours: Total de horas dedicadas al juego.<br>
# * APM (Actions Per Minute): Acciones por minuto, una medida de la velocidad de ejecución de un jugador en el juego.<br>
# * SelectByHotkeys: Número de selecciones de unidades realizadas mediante atajos de teclado por marca de tiempo.<br>
# * AssignToHotkeys: Número de unidades asignadas a teclas de acceso rápido por marca de tiempo.<br>
# * MinimapAttacks: Número de acciones de ataque en el minimapa por marca de tiempo.<br>
# * MinimapRightClicks: Número de clics derecho en el minimapa por marca de tiempo.<br>
# * NumberOfPACs: Número de PACs (Player Action Cycles) por marca de tiempo.<br>
# * GapBetweenPACs: Duración media entre PACs en milisegundos.<br>
# * ActionLatency: Latencia media desde el inicio de los PACs hasta la primera acción en milisegundos.<br>
# * ActionsInPAC: Número medio de acciones dentro de cada PAC.<br>
# * TotalMapExplored: Número de cuadrículas de coordenadas de juego de 24x24 vistas por el jugador por marca de tiempo.<br>
# * WorkersMade: Número de SCVs, drones, probes entrenados por marca de tiempo.<br>
# * UniqueUnitsMade: Unidades únicas creadas por marca de tiempo.<br>
# * ComplexUnitsMade: Número de unidades complejas entrenadas por marca de tiempo.<br>
# * ComplexAbilityUsed: Habilidades complejas utilizadas que requieren instrucciones de destino específicas por marca de tiempo.<br>
# * MaxTimeStamp: Marca de tiempo del último evento registrado en el juego.<br>

# %% [markdown]
# #**Introducción**

# %% [markdown]
# El proyecto semestral de mineria de datos esta basado en la Metodología CRISP-DM (Cross-Industry Standard Process for Data Mining)
# que proporciona un marco robusto y estructurado para abordar proyectos de minería de datos, asegurando que se sigan pasos lógicos y bien definidos desde la comprensión inicial del negocio hasta la implementación exitosa de soluciones basadas en datos.<br><br>
# A continuacion se definen las seis fases de la metodologia Crisp DM que se abordaran durante todo el semestre de manera  detalla donde cada  subseccion es crucial para comprender los datos en profundidad y prepararlos adecuadamente para el análisis y la modelamiento en las fases posteriores del proceso de minería de datos.<br>
# **Fase 1 Comprensión del Negocio:**En esta fase, se busca comprender los objetivos y requisitos del negocio para el proyecto de minería de datos. Se identifican los problemas del negocio, los objetivos a alcanzar y se establece cómo la minería de datos puede contribuir a resolverlos.<br>
#
# **Fase 2 Comprensión de los Datos**: Se recopilan los datos relevantes para el proyecto y se realiza una exploración inicial para comprender su naturaleza. Esta fase incluye la identificación de la calidad de los datos, la detección de valores atípicos y la comprensión de la distribución de las variables.<br>
#
# **Fase 3 Preparación de los Datos:** Los datos recopilados se preparan para el análisis mediante la limpieza, la transformación y la selección de variables relevantes. Se eliminan valores atípicos, se imputan datos faltantes y se convierten los datos en un formato adecuado para el modelado.<br>
#
# **Fase 4 Modelado:** En esta fase, se seleccionan y aplican técnicas de modelado de datos para construir modelos predictivos o descriptivos. Se entrenan los modelos utilizando los datos preparados y se evalúan su desempeño para seleccionar el más adecuado.<br>
#
# **Fase 5 Evaluación:** Se evalúan los modelos desarrollados para determinar su eficacia en la solución de los problemas del negocio. Se realizan pruebas rigurosas y validaciones cruzadas para garantizar la fiabilidad de los resultados.<br>
#
# **Fase 5 Despliegue:** Los modelos evaluados y validados se implementan en el entorno operativo del negocio para su uso continuo. Se desarrollan planes de monitoreo y mantenimiento para asegurar que los modelos sigan siendo efectivos con el tiempo.<br>
#
# Estas fases  se implementa de manera iterativa a lo largo del proyecto de minería de datos. Cada fase no es necesariamente secuencial y puede requerir múltiples iteraciones para lograr los objetivos del proyecto de manera efectiva ya que permite  ajustar y refinar el enfoques a medida que  se avanza en el proyecto,ya que se  obtiene mayor comprensión de los datos y los requisitos del negocio.

# %% [markdown]
# #**1 FASE :  Comprender el negocio**

# %% [markdown]
# ##**1.1. Determinar objetivos empresariales:**

# %% [markdown]
# **1.1.1. Antecedentes:** StarCraft II es un juego de estrategia en tiempo real desarrollado por Blizzard Entertainment. Lanzado en 2010 como la secuela del original StarCraft, el juego presenta tres facciones diferentes: terran, zerg y protoss, que compiten por el control del sector Koprulu en un futuro distante. Destacado por su campaña envolvente y desafiantes misiones, así como su vibrante escena multijugador, StarCraft II ha alcanzado un estatus destacado en los deportes electrónicos.
#
# **1.1.2. Objetivos empresariales:** Los objetivos principales del análisis de datos en StarCraft II son:<BR>
#
#
# **Objetivo Clave:**  Evaluar el Desempeño del Jugador
#
# **KPIs:**
# Índice de Liga: Distribución de los jugadores en diferentes niveles de habilidad (Bronze, Silver, Gold, etc.).
# Acciones por Minuto (APM): Promedio de acciones por minuto para cada liga.
# Acciones de Ataque en el Minimapa: Frecuencia de acciones de ataque en el minimapa por ligaAnalizar el comportamiento de los jugadores en StarCraft II para comprender mejor sus preferencias y patrones de juego.
#
#
# **Objetivo Clave:** Identificar patrones y estrategias comunes utilizadas por los jugadores de StarCraft II.
#
# **KPIs:**
# Número de Selecciones de Unidades por Minuto: Promedio de selecciones de unidades utilizando atajos de teclado por minuto para cada liga.
# Número de Unidades Asignadas a Teclas de Acceso Rápido: Promedio de unidades asignadas a teclas de acceso rápido por minuto por liga.
# Número de PACs por Marca de Tiempo: Promedio de PACs por marca de tiempo por liga.<BR>
#
# **Objetivo Clave:** Predecir la clasificación de los jugadores en función de su estilo de juego y otros factores relevantes.
#
# **KPIs:**
# Precisión de los modelos de predicción de clasificación de jugadores.<BR>
# Porcentaje de jugadores clasificados correctamente en cada liga.<BR>
# Índice de error de las predicciones de clasificación.	<BR>
#
# **Objetivo Clave:** Analizar la Demografía y el Compromiso de los Jugadores
#
# **KPIs:**
# Distribución de la Edad: Proporción de jugadores en diferentes grupos de edad (por ejemplo, adolescentes, adultos jóvenes, adultos mayores).
# Horas Dedicadas al Juego: Promedio de horas por semana dedicadas al juego por grupo de edad.
# Tiempo Total de Juego: Total de horas dedicadas al juego en función de la edad
#
#
# **1.1.3. Éxito empresarial:** El éxito del proyecto se medirá por:<BR>
# •	Precisión en las predicciones de clasificación de jugadores.<BR>
# •	Identificación de patrones útiles y estrategias efectivas.<BR>
# •	Utilidad y aplicabilidad de las recomendaciones generadas.<BR>
# •	Impacto positivo en la experiencia de juego y la comunidad de jugadores.<BR>
#
# **1.1.4. Criterios:** Los criterios para evaluar el éxito del proyecto incluirán:<BR>
# •	Precisión de las predicciones de jugadores.<BR>
# •	Utilidad y relevancia de las recomendaciones generadas.<BR>
# •	Impacto positivo en la experiencia de juego y la comunidad de jugadores.<BR>
# •	Retroalimentación positiva de los usuarios y stakeholders del proyecto<BR>

# %% [markdown]
# ##**1.2. Evaluar la situación:**

# %% [markdown]
# Se evalúa la situación actual del proyecto de mineria de datos en StarCraft II. Esto implica realizar un inventario de recursos disponibles, identificar requisitos, suposiciones y limitaciones, así como analizar los riesgos y contingencias asociados. También se clarifican los términos clave, se examinan los costos y beneficios del proyecto.
#
# **1.2.1 Inventario de recursos:**
#
# ***Recursos humanos:*** El equipo esta compuesto por analistas de datos, científicos de datos, expertos en StarCraft II, que tienen experiencia en mineria  de datos,  una comprensión profunda del juego.
#
# ***Recursos tecnológicos:*** Hardware y software necesarios para mineria de datos.que incluye herramientas de analisis estadistico.
#
# ***Recursos de datos:*** Se tiene un conjuntos de datos de StarCraft II que incluye informacion detallada sobre el juego , como las acciones de los jugadores que estan disponibles para el análisis.<br>
#
# **1.2.2 Requisitos:**
# * Acceso a los datos de StarCraft II, que pueden incluir datos de partidas históricas, datos de jugadores y estadísticas del juego.
# * Habilidades técnicas en mineria  de datos , analisis estadisticos y modelado predictivo para realizar un análisis efectivo de los datos y desarrollar modelos predictivos precisos.
#
# * Comprensión profunda del juego y su mecánica para interpretar adecuadamente los datos y generar recomendaciones significativas para los jugadores
#
# **1.2.3 Suposiciones y restricciones:**
#
# ***Suposición***: Se supone que los  datos proporcionados son representativos del comportamiento de los jugadores en StarCraft II y que pueden ser utilizados para analizar patrones y tendencias del juego.<br>
# ***Restricción:*** Exisre una limitación en la disponibilidad de datos históricos para análisis, lo que puede afectar la capacidad de realizar analisis retrospectivos y modelado predictivo a largo plazo.
#
# ***1.2.4 Riesgos y contingencias:***
#
# ***Riesgo:*** La  precisión en las predicciones se puede ver dificultada debido a la complejidad del juego y las estrategia de cada jugador.<br>
# ***Contingencia: ***Se realizan pruebas rigurosas de modelos predictivos para mitigar el riesgo de falta de precision en las predicciones .<br>
#
# **1.2.5 Terminología:**
# APM (Actions Per Minute): Acciones por minuto, una medida de la velocidad de ejecución de un jugador en el juego.<br>
# PACs (Player Action Cycles): Ciclos de acciones que realiza cada jugador durante cada partida, que puede entregar informacion sobre las estrategias utilizadas y el estilo de juego de cada jugador.<br>
#
# ***1.2.6 Costos y beneficios:***<br>
# ***Costos:*** Se incluyen los recursos humanos, tecnológicos y de datos para la mineria de datos.Tambien los costos asociados en mantenimiento y actualizaciones de plataforma y herramientas para el analisis de datos <br>
# ***Beneficios:*** Mejora en la comprensión del juego,se generan  recomendaciones para jugadores. Tambien se potencia el impacto positivo en la experiencia de juego y en la comunidad de jugadores.

# %% [markdown]
# ##**1.3. Determinar los objetivos de la minería de datos:**

# %% [markdown]
# **1.3.1. Objetivos de la minería de datos:**<br>
#
# ***Identificar patrones de juego***:Se analizan los datos de juego para descubrir patrones y tendencias en el comportamiento de los jugadores durante las partidas, como estrategias utilizadas, eficiencia en la gestión de recursos y tácticas de combate.<br>
#
# ***Predecir el rendimiento del jugador***: Se desarrollan  modelos predictivos que puedan predecir el rendimiento de los jugadores en función de variables como la edad, las horas dedicadas al juego, la velocidad de ejecución de acciones (APM), y el uso de tácticas específicas.<br>
#
# ***Generar recomendaciones para mejorar el juego***:Se utilizan los resultados del análisis para generar recomendaciones personalizadas a los jugadores, como estrategias específicas para enfrentar a ciertas razas, tácticas  y consejos para mejorar la eficiencia en la toma de decisiones durante las partidas.<br>
#
# **1.3.2. Éxito en la minería de datos:**
#
# ***Precisión de las predicciones:*** Se debe evaluar la precisión de los modelos predictivos en la predicción del rendimiento del jugador y la identificación de patrones de juego, mediante la comparación de las predicciones con los datos reales del juego.<br>
#
# **Utilidad de las recomendaciones:*** Se debe medir la utilidad y relevancia de las recomendaciones generadas para mejorar la experiencia de juego de los jugadores, mediante encuestas y retroalimentación directa de la comunidad de jugadores.<br>
#
# **Impacto en la comunidad de jugadores:**Se evalua el impacto positivo de la minería de datos en la comunidad de jugadores de StarCraft II, en términos de participación, satisfacción y retención de jugadores, mediante el seguimiento de métricas como la actividad en el juego y la permanencia de los jugadores en la comunidad.<br>
#
# **1.3.3. Criterios:**<br>
#
# ***Precisión de las predicciones:*** Los modelos predictivos deben tener una alta precisión en la predicción del rendimiento del jugador y la identificación de patrones de juego, con una tasa de error mínima.<br>
#
# ***Utilidad de las recomendaciones***: Las recomendaciones generadas deben ser útiles y aplicables para mejorar la experiencia de juego de los jugadores, reflejadas en una mejora en su desempeño y resultados en las partidas.<br>
#
# ***Impacto en la comunidad:*** Este proyecto de minería de datos debe tener un impacto positivo en la comunidad de jugadores, demostrado a través de un aumento en la participación, satisfacción y retención de los jugadores en la comunidad de StarCraft II.

# %% [markdown]
# ##**1.4. Elaborar un plan de proyecto:**

# %% [markdown]
# ###**1.4.1. Plan de proyecto:**
#
# El plan de proyecto para la minería de datos en StarCraft II se desarrollará teniendo en cuenta los siguientes pasos:
#
# ***Definición de objetivos:*** Refinar y detallar los objetivos de la minería de datos, asegurando que estén alineados con las necesidades del negocio y los requisitos de los jugadores.
#
# ***Recopilación de datos***: Adquiere el conjuntos de datos necesarios de StarCraft II, el cual se encuentra en formato excel, asegurando la calidad y la integridad de los datos.
#
# ***Preprocesamiento de datos:*** Se realiza la limpieza, integración y transformación de datos para prepararlos para el análisis.
#
# ***Análisis exploratorio de datos***: Se exploran los datos para identificar patrones, tendencias y relaciones importantes que puedan ser util para  el análisis y posterior modelado.
#
# ***Modelado predictivo:*** Desarrollar modelos predictivos utilizando técnicas de aprendizaje automático y estadísticas para predecir el rendimiento del jugador y generar recomendaciones.
#
# ***Evaluación de modelos:*** Se evalua la precisión y el rendimiento de los modelos predictivos utilizando métricas como la precisión, la sensibilidad, la especificidad, el área bajo la curva ROC (AUC-ROC), el error cuadrático medio (MSE), el error absoluto medio (MAE) y la precisión del modelo para evaluar el rendimiento del modelo en conjunto con el conjunto de datos de prueba.
#
# ***Generación de recomendaciones:*** Utilizar los modelos predictivos para generar recomendaciones personalizadas para los jugadores, basadas en su estilo de juego y características individuales.
#
# ***Implementación y seguimiento:*** Implementar las recomendaciones en la comunidad de jugadores de StarCraft II y realizar un seguimiento del impacto y la efectividad de las recomendaciones en la mejora de la experiencia de juego.<br><br>
#
# ###**1.4.2. Evaluación inicial de herramientas y técnicas:**
#
# * *Herramientas de minería de datos:* Se utilizará Google Colab como plataforma principal para el desarrollo del proyecto. Se evaluarán las bibliotecas de Python como Pandas, Scikit-learn y TensorFlow para el análisis y modelado de datos, asegurando su compatibilidad con Google Colab
#
# * *Técnicas de análisis de datos:* Se explorarán técnicas de análisis estadístico, aprendizaje automático y minería de texto compatibles con Google Colab, como regresión y  clasificación.
#
# * *Plataformas de computación*: Google Colab proporciona recursos de computación gratuitos en la nube y es compatible con Python, lo que facilita el procesamiento de grandes volúmenes de datos de StarCraft II
#
# * *Métricas de evaluación:* Se identificarán métricas de evaluación adecuadas para medir la precisión, el rendimiento y la utilidad de los modelos predictivos y las recomendaciones generadas en Google Colab. Se considerarán métricas como precisión, sensibilidad, especificidad y área bajo la curva ROC.

# %% [markdown]
# #**2 FASE : Comprender los datos**

# %% [markdown]
#  Comprende la recolección inicial de datos,tiene como objetivo establecer un primer acercamiento con el problema, conociendo a los datos, identificando su calidad y examinan las propiedades del set de datos que se tiene para establecer las primeras relaciones.

# %% [markdown]
# ##**2.1 Recopilación inicial de datos:**
#  En esta etapa, se recopilan los datos iniciales necesarios para el proyecto de minería de datos. Los datos se obtienen de una base de datos llamada starcraft_duoc.csv.

# %% [markdown]
# **2.1.1 Recolección de datos:** Consiste en obtener los datos a utilizar en el proyecto a partir de algunas fuentes de datos, e identificando las técnicas utilizadas para su recolección.
#  Se carga el archivo "starcraft_duoc.csv" en Google Colab y se prepara para explorar y analizar los datos en el siguiente paso del proyecto.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# **Carga de datos**
# Se carga el archivo starcraft_duoc.csv en un DataFrame de Pandas en el entorno de Colab.

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
    name=fn
df = pd.read_csv(name, sep=";")
df.head(20
        )
# Out:
#      <input type="file" id="files-74c9cd0a-11fd-4f28-b894-f8ee49131f54" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74c9cd0a-11fd-4f28-b894-f8ee49131f54">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Tamaño del Dataset**

# %%
df.shape
# Out:
# (3395, 20)

# %% [markdown]
# **Informacion columnas**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3395 entries, 0 to 3394
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   GameID              3395 non-null   int64
#  1   LeagueIndex         3395 non-null   int64
#  2   Age                 3340 non-null   float64
#  3   HoursPerWeek        3339 non-null   float64
#  4   TotalHours          3338 non-null   float64
#  5   APM                 3395 non-null   object
#  6   SelectByHotkeys     3395 non-null   object
#  7   AssignToHotkeys     3395 non-null   object
#  8   MinimapAttacks      3395 non-null   object
#  9   MinimapRightClicks  3395 non-null   object
#  10  NumberOfPACs        3395 non-null   float64
#  11  GapBetweenPACs      3395 non-null   object
#  12  ActionLatency       3395 non-null   object
#  13  ActionsInPAC        3395 non-null   float64
#  14  TotalMapExplored    3395 non-null   float64
# ...

# %% [markdown]
# **Valores nulos**

# %%
# Valores nulos
for feature in df.columns:
  print('Total de valores nulos de', feature, '=', df[feature].isna().sum())
# Out:
# Total de valores nulos de GameID = 0
# Total de valores nulos de LeagueIndex = 0
# Total de valores nulos de Age = 55
# Total de valores nulos de HoursPerWeek = 56
# Total de valores nulos de TotalHours = 57
# Total de valores nulos de APM = 0
# Total de valores nulos de SelectByHotkeys = 0
# Total de valores nulos de AssignToHotkeys = 0
# Total de valores nulos de MinimapAttacks = 0
# Total de valores nulos de MinimapRightClicks = 0
# Total de valores nulos de NumberOfPACs = 0
# Total de valores nulos de GapBetweenPACs = 0
# Total de valores nulos de ActionLatency = 0
# Total de valores nulos de ActionsInPAC = 0
# Total de valores nulos de TotalMapExplored = 0
# Total de valores nulos de WorkersMade = 0
# Total de valores nulos de UniqueUnitsMade = 0
# Total de valores nulos de ComplexUnitsMade = 0
# Total de valores nulos de ComplexAbilityUsed = 0
# Total de valores nulos de MaxTimeStamp = 0

# %% [markdown]
# ###**2.1.2 Informe**

# %% [markdown]
# Se realiza un informe de los datos recopilados que entrega una visión general de los datos recopilados, se incluye la fuente, el formato y los problemas iniciales identificados. Este análisis inicial es fundamental para comprender la naturaleza de los datos y planificar adecuadamente los pasos a seguir en el proyecto de análisis de StarCraft II<br>
#  El tamaño del set de datos está formado por filas 3395 que corresponden a las observaciones y columnas 20 que son las características (features, variables)
# <br>
# * ***Fuente de los datos***: Los datos fueron obtenidos de una fuente que recopila
# información sobre las partidas de StarCraft II.
#
# * ***Formato de los datos:*** Los datos están organizados en formato CSV , lo que facilita la lectura y manipulación de estos, utilizando herramientas como Pandas en Python.
#
# * ***Informacion de las variables ***<br>
# Tipos de datos:
# * 6 columnas son de tipo float64.
# * 3 columnas son de tipo int64 .
# * 11 columnas son de tipo object.<br>
#
# Cantidad de variables: 20 <br>
#
# Nombre y descripcion de cada variable:<br>
# GameID: Identificador único para cada partida.<br>
# LeagueIndex: Índice de liga, que varía de 1 a 8 y representa diferentes niveles de habilidad de los jugadores.<br>
# Age: Edad de cada jugador.<br>
# HoursPerWeek: Horas dedicadas al juego por semana.<br>
# TotalHours: Total de horas dedicadas al juego.<br>
# APM (Actions Per Minute): Acciones por minuto, una medida de la velocidad de ejecución de un jugador en el juego.<br>
# SelectByHotkeys: Número de selecciones de unidades realizadas mediante atajos de teclado por marca de tiempo.<br>
# AssignToHotkeys: Número de unidades asignadas a teclas de acceso rápido por marca de tiempo.<br>
# MinimapAttacks: Número de acciones de ataque en el minimapa por marca de tiempo.<br>
# MinimapRightClicks: Número de clics derecho en el minimapa por marca de tiempo.<br>
# NumberOfPACs: Número de PACs (Player Action Cycles) por marca de tiempo.<br>
# GapBetweenPACs: Duración media entre PACs en milisegundos.<br>
# ActionLatency: Latencia media desde el inicio de los PACs hasta la primera acción en milisegundos.<br>
# ActionsInPAC: Número medio de acciones dentro de cada PAC.<br>
# TotalMapExplored: Número de cuadrículas de coordenadas de juego de 24x24 vistas por el jugador por marca de tiempo.<br>
# WorkersMade: Número de SCVs, drones, probes entrenados por marca de tiempo.<br>
# UniqueUnitsMade: Unidades únicas creadas por marca de tiempo.<br>
# ComplexUnitsMade: Número de unidades complejas entrenadas por marca de tiempo.<br>
# ComplexAbilityUsed: Habilidades complejas utilizadas que requieren instrucciones de destino específicas por marca de tiempo.<br>
# MaxTimeStamp: Marca de tiempo del último evento registrado en el juego.<br>
#
# * *Problemas iniciales identificados:*<br>
#
# Algunas características numéricas están almacenadas como tipo de dato object, lo que indica que podrían tener algún tipo de formato no numérico o estar representadas de manera incorrecta. Esto puede afectar la capacidad de realizar cálculos estadísticos y análisis sobre esas características. Las columnas de tipo object son :  APM, SelectByHotkeys, AssignToHotkeys, MinimapAttacks, MinimapRightClicks, GapBetweenPACs, ActionLatency, WorkersMade, UniqueUnitsMade, ComplexUnitsMade y ComplexAbilityUsed.<br>
#
#
# Existen datos faltantes en las variables de Age, HoursPerWeek y TotalHours , lo cual puede afectar la integridad y la precisión del análisis. Este problema se tratara mediantes ciertas tecnicas como:
# 1. Eliminar las observaciones
# 2. Imputación . Acá se rellenan los valores vacíos con algún valor, puede ser el promedio del valor de la columna. Puede ser el valor más repetido en el caso de una variable categórica.
# 3. Una extensión de la imputación. Se agrega una columna indicando que el valor ha sido reemplazado, de esta forma, se mantiene “identificados” a los valores nulo. Estas tecnicas se abordan  durante el proceso de limpieza de datos, ya que  si no se manejan adecuadamente, los datos faltantes podrían sesgar los resultados o hacer que los modelos predictivos sean menos confiables.<br>

# %% [markdown]
# ##**2.2 Descripción de los datos:**

# %% [markdown]
#  Se realiza una descripción detallada de los datos recopilados, incluyendo estadísticas descriptivas, distribuciones de variables, tipos de datos

# %% [markdown]
# ###**Variables Numericas**

# %% [markdown]
# **Estadistica descriptiva**

# %%
# Calculamos estadísticas descriptivas para características numéricas
df.describe()
# Out:
#              GameID  LeagueIndex          Age  HoursPerWeek      TotalHours  \
# count   3395.000000  3395.000000  3340.000000   3339.000000     3338.000000
# mean    4805.012371     4.184094    21.647904     15.910752      960.421809
# std     2719.944851     1.517327     4.206341     11.962912    17318.133922
# min       52.000000     1.000000    16.000000      0.000000        3.000000
# 25%     2464.500000     3.000000    19.000000      8.000000      300.000000
# 50%     4874.000000     4.000000    21.000000     12.000000      500.000000
# 75%     7108.500000     5.000000    24.000000     20.000000      800.000000
# max    10095.000000     8.000000    44.000000    168.000000  1000000.000000
#
#        NumberOfPACs  ActionsInPAC  TotalMapExplored   MaxTimeStamp
# count   3395.000000   3395.000000       3395.000000    3395.000000
# mean       0.003463     47.216492          0.000283   83598.229161
# std        0.000992     20.604812          0.000087   33497.667966
# ...

# %% [markdown]
# Algunas características tienen valores atípicos  que necesitan ser identificados y tratados durante el proceso de limpieza de datos. La presencia de valores atípicos puede distorsionar las estadísticas descriptivas y afectar la precisión de los modelos predictivos. Se pueden  encontrar valores extremadamente altos o bajos en las características relacionadas con las horas de juego que podrían ser errores de entrada o datos no representativos

# %% [markdown]
# **Distribuciones de las variables**

# %%
# Seleccionar solo las variables numéricas para calcular la correlación
numericas_df = df.select_dtypes(include='number')

# %% [markdown]
# **Histograma**

# %% [markdown]
# Este gráfico es útil para comprender la distribución de cada variable y asi  detectar si la distribucion es normal o sesgada.Los ejes x e y del histograma representan los rangos y la frecuencia. También puede ayudar a identificar valores atípicos o valores extremos en las variables

# %%
for column in numericas_df:
    sns.displot(df[column], kde=True)
    plt.title(f'Distribución de {column}')
    plt.xlabel(column)
    plt.ylabel('Frecuencia')
    plt.show()

# %% [markdown]
# Podemos ver que características como HoursPerweek, Age, MaxTimeStamp estan sesgadas hacia la derecha.Esto ocurre  en HoursPerWeek ya que hay algunos jugadores que dedican una cantidad extremadamente alta de horas a jugar StarCraft II. En Age ocurre que  hay algunos jugadores mayores que están fuera del rango típico de edad de los jugadores.<br>
#
# Este tipo de sesgo puede tener implicaciones en el análisis de datos y en la interpretación de los resultados, ya que los valores extremadamente altos pueden afectar la media y otras estadísticas descriptivas de la distribución. Es importante tener en cuenta este sesgo al realizar análisis estadísticos y modelado de datos.<br>

# %% [markdown]
#  Age: revela que la mayoría de los jugadores de StarCraft II tienen entre 20 y 22 años, ya que la moda está en 20 años y la mediana en 21 años. Esto sugiere que la población de jugadores está compuesta principalmente por jóvenes . Además, la dispersión alrededor de la media (21.65 años) es relativamente baja, con una desviación estándar de aproximadamente 4.21 años, lo que indica que la mayoría de los jugadores se encuentran dentro de un rango de edad estrecho. Este **insight** puede ser útil para la segmentación de la audiencia y la personalización de estrategias de marketing y desarrollo de productos orientadas a este grupo demográfico específico.
#
#  HoursPerWeek:Esta variable indica el número de horas que los jugadores dedican al juego por semana. La media es aproximadamente 15 horas por semana, pero hay una gran variabilidad con una desviación estándar de casi 12 horas. Además, hay un valor máximo inusualmente alto de 168 horas por semana, lo que podría ser un valor atípico<br>
#
#  TotalHours:Esta variable indica el total de horas jugadas por cada jugador. La media es de aproximadamente 960 horas, pero la gran desviación estándar indica una gran variabilidad en los datos. Además, hay un valor máximo muy alto de 1000000 horas, lo que indica la presencia de valores atípicos

# %% [markdown]
# **Diagramas de dispersión o boxplots**
#
# Identificar posibles sesgos o tendencias

# %%
# Visualización de la distribución de las variables numéricas
sns.pairplot(df)
plt.show()

# %% [markdown]
# ###**Variables categoricas**

# %%
# Seleccionar solo las variables categoricas
categoricas_df = df.select_dtypes(include='object')

# %%
df.describe(include=[object])
# Out:
#             APM SelectByHotkeys AssignToHotkeys MinimapAttacks  \
# count      3395            3395            3395           3395
# unique     3374            3373            3306           1728
# top     143.718               0               0              0
# freq          2              16               6            877
#
#        MinimapRightClicks GapBetweenPACs ActionLatency WorkersMade  \
# count                3395           3395          3395        3395
# unique               3159           3358          3367        3256
# top                     0             52       666.667    0.001134
# freq                   72              3             2           4
#
#        UniqueUnitsMade ComplexUnitsMade ComplexAbilityUsed
# count             3395             3395               3395
# unique            1367             1059               1658
# top           7.26e-05                0                  0
# freq                14             2281               1552

# %% [markdown]
# Unique: Representa el número de valores únicos en una variable categórica.<br>
# Top: Es el valor más frecuente en una variable categórica, es decir, el valor que aparece con mayor frecuencia.<br>
# Freq: Indica la frecuencia con la que aparece el valor más frecuente (Top) en la variable categórica<br>

# %% [markdown]
# ###**2.2.1 Informe**

# %% [markdown]
# Se genera un informe que resume la descripción de los datos, destacando patrones interesantes o hallazgos relevantes

# %% [markdown]
# ####**Variables numericas**

# %% [markdown]
# Estadistica descriptiva para 9 Variables numéricas del dataset<br>
#
# GameID: El ID único del juego.<br>
# LeagueIndex: El índice de la liga del jugador.<br>
# Age: La edad del jugador.<br>
# HoursPerWeek: Las horas que el jugador pasa jugando por semana.<br>
# TotalHours: El total de horas que el jugador ha jugado.<br>
# NumberOfPACs: El número de PACs (Player Action Cycles) por timestamp.<br>
# ActionsInPAC: El número medio de acciones dentro de cada PAC.<br>
# TotalMapExplored: El número de cuadrículas de coordenadas de juego 24x24 vistas por el jugador por timestamp.<br>
# MaxTimeStamp: El timestamp del último evento registrado del juego<br>

# %% [markdown]
# Observaciones
# * Se puede observar que la edad promedio de los jugadores es de aproximadamente 21 años, con un rango que va desde los 16 hasta los 44 años.
# * El total de horas jugadas varía significativamente, con una desviación estándar bastante alta
# * GameID: Este es un identificador único para cada juego en el conjunto de datos. No parece proporcionar información útil sobre los jugadores o su desempeño en el juego, ya que es solo un identificador.
# * LeagueIndex: Este es un indicador del nivel de habilidad del jugador, variando de 1 a 8 para diferentes ligas. La mayoría de los jugadores parecen estar en ligas más bajas, ya que la media está alrededor de 4.18 y el 75% de los jugadores tienen un índice de liga de 5 o menos.
#
# * HoursPerWeek: El promedio aproximadamente 15.91 horas por semana que pasan los jugadores jugando StarCraft II. Sin embargo, esta característica muestra una amplia variabilidad, con un rango desde 0 hasta 168 horas por semana.
#
# * TotalHours: El total de horas que los jugadores han pasado jugando StarCraft II varía significativamente, con una media de aproximadamente 960.42 horas. Sin embargo, hay una gran desviación estándar, lo que indica una amplia dispersión en el tiempo total jugado por los jugadores.
#
# * NumberOfPACs: La cantidad de PACs por timestamp es bastante baja, con un promedio de 0.003463. Esto sugiere que los jugadores no realizan muchas acciones en el juego en comparación con otros eventos que se registran.
#
# * ActionsInPAC: El número medio de acciones dentro de cada PAC es de aproximadamente 47.22. Esto puede indicar la complejidad de las acciones que los jugadores realizan en cada ciclo de acción.
#
# * TotalMapExplored: El  promedio de 0.000283 es muy bajo . Esto sugiere que la exploración del mapa puede no ser una actividad frecuente en el juego.
#
# * En la columna "HoursPerWeek", el valor mínimo es 0 y el valor máximo es 168. Un valor de 0 horas por semana de juego y  un valor maximo de 168 horas por semana (equivalente a 24 horas al día) lo cual es poco probable y podría ser un error o una entrada incorrecta.
#
# * En la columna "TotalHours", el valor mínimo es 3 y el valor máximo es 1,000,000.El valor máximo de 1,000,000 horas de juego es extremadamente alto y es probable que sea un dato erróneo o una entrada incorrecta.

# %% [markdown]
# ####**Variables categoricas**

# %% [markdown]
# Cantidad de variables categoricas son : 11.<br>
# Nombre variables categoricas: APM	,SelectByHotkeys,	AssignToHotkeys,	MinimapAttacks,	MinimapRightClicks,	GapBetweenPACs,	ActionLatency,	WorkersMade	,UniqueUnitsMade,	ComplexUnitsMade,	ComplexAbilityUsed.
# <br><br>
# Observaciones:<br>
# <br>
# APM <br>
# * Unique: Hay 3374 valores únicos en el conjunto de datos que casi igual a o al recuento total de datos (count), esto indica que hay una amplia variedad de valores diferentes en esta variable.<br>
# * Top: El valor más frecuente es 143.718 acciones por minuto que es la moda .
# * Freq: Este valor aparece 2 veces en el conjunto de datos.
# * La distribución de las acciones por minuto (APM) muestra una amplia variedad de valores únicos, con un valor de 143.718 siendo el más común. Esto sugiere que hay una diversidad en la velocidad de ejecución de los jugadores durante el juego.
# <br>
# SelectByHotkeys:<br>
#
# * Unique: Hay 3373 valores únicos en la variable SelectByHotkeys.
# * Top: El valor más frecuente es 0, lo que sugiere que la mayoría de las veces no se utilizan atajos de teclado para seleccionar unidades.
# * Freq: El valor 0 aparece 16 veces en el conjunto de datos.
# *  La mayoría de las veces, los jugadores no están utilizando atajos de teclado para seleccionar unidades, lo que podría indicar una preferencia por otros métodos de selección en el juego.
# <br>
# AssignToHotkeys:<br>
#
# * Unique: Hay 3306 valores únicos en la variable AssignToHotkeys.
# * Top: El valor más frecuente es 0, lo que indica que la mayoría de las veces no se asignan unidades a atajos de teclado.
# * Freq: El valor 0 aparece 6 veces en el conjunto de datos.
# * La mayoría de las veces, los jugadores no asignan unidades a atajos de teclado, lo que sugiere que pueden preferir otros métodos de asignación

# %% [markdown]
# ##**2.3 Exploración de los datos:**

# %% [markdown]
#  Se basa en aplicar pruebas estadísticas que permitan conocer las propiedades de los datos.Se lleva a cabo una exploración más profunda de los datos para identificar tendencias, patrones y relaciones entre las variables.Se realiza visualización de datos, análisis de correlación, entre otros.

# %% [markdown]
# **Correlacion**

# %%
# Correlación entre variables
correlacion = numericas_df.corr()
correlacion
# Out:
#                     GameID  LeagueIndex       Age  HoursPerWeek  TotalHours  \
# GameID            1.000000     0.102601  0.088863     -0.025456    0.004178
# LeagueIndex       0.102601     1.000000 -0.127825      0.217976    0.023884
# Age               0.088863    -0.127825  1.000000     -0.184508   -0.016630
# HoursPerWeek     -0.025456     0.217976 -0.184508      1.000000    0.024306
# TotalHours        0.004178     0.023884 -0.016630      0.024306    1.000000
# NumberOfPACs      0.089635     0.612192 -0.197282      0.174948    0.039577
# ActionsInPAC      0.029246     0.105229 -0.030476      0.080756    0.012322
# TotalMapExplored  0.014878     0.232982 -0.090594      0.061180    0.026362
# MaxTimeStamp      0.010014    -0.003790  0.042930      0.006740   -0.004556
#
#                   NumberOfPACs  ActionsInPAC  TotalMapExplored  MaxTimeStamp
# GameID                0.089635      0.029246          0.014878      0.010014
# ...

# %% [markdown]
#  La falta de correlación entre la mayoria de las variables puede deberse a valores faltantes o errores en los datos. Es necesario realiza una limpieza de los datos para abordar estos problemas.

# %% [markdown]
# **Grafico de calor**

# %%
# Calcular la matriz de correlación
correlation_matrix = numericas_df.corr()

# Visualizar la matriz de correlación utilizando un mapa de calor
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de correlación')
plt.show()

# %% [markdown]
# Los valores de correlación , donde -1 indica una correlación negativa perfecta, 1 indica una correlación positiva perfecta y 0 indica una ausencia de correlación.Los colores del mapa de calor indican el valor de correlación, siendo los tonos más azul para valores negativos y los tonos más rojos para valores positivos.Este gráfico es útil para identificar patrones y relaciones entre las variables.Determina las variables altamente correlacionadas y si existen relaciones lineales o no lineales entre las variables. <br>
# Al observar las variables que tienen mayor correlacion es LeagueIndex y NumberOfPACs con una correlacion de 0.61 la cual se acerca mas a una relacion lineal positiva entre ellas.

# %% [markdown]
# **Datos Faltantes**

# %%
# Verificar valores faltantes en cada columna
missing_values = df.isnull().sum()
missing_values
# Out:
# GameID                 0
# LeagueIndex            0
# Age                   55
# HoursPerWeek          56
# TotalHours            57
# APM                    0
# SelectByHotkeys        0
# AssignToHotkeys        0
# MinimapAttacks         0
# MinimapRightClicks     0
# NumberOfPACs           0
# GapBetweenPACs         0
# ActionLatency          0
# ActionsInPAC           0
# TotalMapExplored       0
# WorkersMade            0
# UniqueUnitsMade        0
# ComplexUnitsMade       0
# ComplexAbilityUsed     0
# MaxTimeStamp           0
# dtype: int64

# %% [markdown]
# **Outliers**

# %%
# Definición de las variables con los estadísticos descriptivos
Q1 = numericas_df.quantile(0.25)
Q3 = numericas_df.quantile(0.75)
IQR = Q3 - Q1

# Identificación de outliers
outliers = ((numericas_df < (Q1 - 1.5 * IQR)) | (numericas_df > (Q3 + 1.5 * IQR))).sum()
print("Cantidad de outliers por variable:")
print(outliers)
# Out:
# Cantidad de outliers por variable:
# GameID                0
# LeagueIndex           0
# Age                  98
# HoursPerWeek        171
# TotalHours          169
# NumberOfPACs         58
# ActionsInPAC        448
# TotalMapExplored    107
# MaxTimeStamp         60
# dtype: int64

# %% [markdown]
# **Diagrama de caja**

# %%
# Crear el diagrama de caja para todas las variables numéricas
plt.figure(figsize=(12, 6))
sns.boxplot(data=numericas_df)
plt.title('Diagrama de Caja para Variables Numéricas')
plt.xlabel('Variables')
plt.ylabel('Valor')
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para mejorar la legibilidad
plt.show()

# %% [markdown]
# ##**2.3.1 Informe**:
#
#  Se documentan los resultados de la exploración de datos, destacando cualquier hallazgo significativo o insight obtenido durante el proceso de exploración.

# %% [markdown]
# **Variable "MaxTimeStamp"**: representa la marca de tiempo del último evento registrado en el juego. Los datos muestran que el valor mínimo es 25224 y el máximo es 388032. El promedio de las marcas de tiempo es aproximadamente 83598, con una desviación estándar de alrededor de 33497.La desviación estándar, que es una medida de dispersión de los datos, es relativamente alta, lo que indica que los valores están bastante dispersos alrededor de la media. Esto indica que hay una variabilidad significativa en el tiempo de los eventos registrados. Al observar los cuartiles, vemos que el 25% de las marcas de tiempo están por debajo de 60090, el 50% está por debajo de 81012 y el 75% está por debajo de 102074. Esto sugiere que la mayoría de los eventos ocurrieron dentro de un rango de tiempo relativamente limitado.
#  <br>
# El **coeficiente de correlacion** es 0.61, esto nos dice que si existe una correlacion fuerte entre las variables LeagueIndex y NumberOfPACs.Las variables estan asociadas en sentido directo y una relación lineal positiva. Inferimos vez que cuando aumenta el nivel LeagueIndex ,tambien aumenta el  número de PACs por timestamp.La relacion de las variables es  directamente proporcional. Aunque tambien se ve que hay varios datos dispersos.<br>
#
# **Los valores faltantes** Se encuentran en las columnas 'Age', 'HoursPerWeek' y 'TotalHours'. Aquí está la cantidad de valores faltantes para cada una de estas columnas:<br>
#
# 'Age': 55 valores faltantes<br>
# 'HoursPerWeek': 56 valores faltantes<br>
# 'TotalHours': 57 valores faltantes<br>
# Estos valores faltantes deben tratarse para realizar el análisis y modelado de datos, ya que pueden afectar la precisión y validez de los resultados. Estos se pueden imputar, eliminar o considerar otras estrategias de manejo de datos faltantes.
#
#   **Outlier** las variables tienen valores atípicos:<br>
#
# * Age: Hay 98 valores atípicos en la variable de edad. Esto indica la presencia de jugadores cuya edad está significativamente fuera del rango típico.
#
# * HoursPerWeek: Se encontraron 171 outliers en esta variable. Indica que los jugadores  dedican un número excepcionalmente alto o bajo de horas al juego por semana.
#
# * TotalHours: Hay 169 outliers . Indica que estos jugadores tienen  un tiempo total de juego inusualmente alto o bajo.
#
# * NumberOfPACs: Tiene  58 outliers. Indica lo que  algunos jugadores realizan un número excepcionalmente alto o bajo de ciclos de acción del jugador durante las partidas.
#
# * ActionsInPAC: Se encuentran  448 outliers en esta variable sugiere que algunos jugadores tienen una cantidad inusualmente alta o baja de acciones dentro de cada ciclo de acción del jugador.
#
# * TotalMapExplored: Hay 107 outliers, puede indicar que algunos jugadores exploran un número excepcionalmente alto o bajo de cuadrículas de coordenadas de juego durante las partidas.
#
# * MaxTimeStamp: Se encontraron 60 outliers , esto refleja  eventos registrados en momentos extremadamente inusuales durante las partidas

# %% [markdown]
# ##**2.4 Verificación de la calidad de los datos:**

# %% [markdown]
#  Se evalúa la calidad de los datos recopilados mediante la identificación y el tratamiento de problemas como valores faltantes, valores atípicos, errores de formato, etc. Se genera un informe que resume los hallazgos y las acciones tomadas para mejorar la calidad de los datos.

# %% [markdown]
# ###**Informe sobre la calidad de los datos:**
#
# **Identificación de problemas de calidad de datos:**
#
# * Valores faltantes:
#
# Se identificaron valores faltantes en las variables "Age", "HoursPerWeek", "TotalHours" y "MaxTimeStamp". La variable "Age" tiene 98 valores faltantes, "HoursPerWeek" tiene 171, "TotalHours" tiene 169 y "MaxTimeStamp" tiene 60.
# Valores atípicos:
#
# * Valores atípicos :En las variables numéricas "GameID", "Age", "HoursPerWeek", "TotalHours" y "MaxTimeStamp". Se utilizaron diagramas de caja para visualizar estas anomalías y se identificaron registros con valores extremos que podrían afectar el análisis.
#
# * Errores de formato:
# En las variables categóricas sería recomendable convertir estas variables a un formato numérico adecuado para garantizar la precisión y la integridad del análisis de datos.
#
# **Tratamiento de problemas de calidad de datos**:
#
# * Valores faltantes:
#
# Se  imputaran  los valores faltantes en las variables "Age", "HoursPerWeek" y "TotalHours" utilizando la mediana de cada variable.
# Para la variable "MaxTimeStamp", se optara por eliminar los registros con valores faltantes debido a su naturaleza crítica para el análisis..
#
# * Valores atípicos:
#
# Se conservaran los valores atípicos en las variables numéricas, ya que podrían contener información valiosa sobre jugadores extremadamente habilidosos o situaciones excepcionales en el juego.Se deben analizar.
#
# * Errores de formato:
#
# Se realizaran conversiones de formato para las variables categoricas ,para asegurar que estén representadas con un tipo de dato numerico para  el análisis posterior.
